# %%
MYPROJECT = '/home/vimm/code/spring_exercise/stock_simulation_analysis/stock_simulation_analysis'
import os, sys
sys.path.insert(0, MYPROJECT)
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "settings")
import django
django.setup()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a443658c362a> in <module>()
#       4 os.environ.setdefault("DJANGO_SETTINGS_MODULE", "settings")
#       5 import django
# ----> 6 django.setup()
#       7 import numpy as np
#       8 import pandas as pd
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\__init__.py in setup(set_prefix)
#      20     from django.utils.log import configure_logging
#      21
# ---> 22     configure_logging(settings.LOGGING_CONFIG, settings.LOGGING)
#      23     if set_prefix:
#      24         set_script_prefix(
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      54         """
#      55         if self._wrapped is empty:
# ---> 56             self._setup(name)
#      57         val = getattr(self._wrapped, name)
#      58         self.__dict__[name] = val
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      39                 % (desc, ENVIRONMENT_VARIABLE))
#      40
# ---> 41         self._wrapped = Settings(settings_module)
#      42
#      43     def __repr__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\conf\__init__.py in __init__(self, settings_module)
#     108         self.SETTINGS_MODULE = settings_module
#     109
# --> 110         mod = importlib.import_module(self.SETTINGS_MODULE)
#     111
#     112         tuple_settings = (
#
# C:\ProgramData\Anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'settings'

# %%
from django_pandas.io import read_frame

from stock_api.models import StockData
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
qs = StockData.objects.all()
df = read_frame(qs)

# %%
data = df['open']
stock_data = np.array(data.values.reshape((len(data),1)))
stock_data.shape #(1257, 1)
stock_data[:2]

# %%
# Split the data into training/testing sets
stock_X_train = stock_data[:500]
stock_X_test = stock_data[1000:1127,]

# Split the targets into training/testing sets
stock_y_train = stock_data[500:1000]
stock_y_test = stock_data[1127:1254]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e6499e2cf9b6> in <module>()
#       1 # Split the data into training/testing sets
# ----> 2 stock_X_train = stock_data[:500]
#       3 stock_X_test = stock_data[1000:1127,]
#       4
#       5 # Split the targets into training/testing sets
#
# NameError: name 'stock_data' is not defined

# %%
regr = linear_model.LinearRegression()
regr.fit(stock_X_train, stock_y_train)
stock_y_pred = regr.predict(stock_X_test)

# %%
 stock_y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af07c405752e> in <module>()
# ----> 1 stock_y_pred
#
# NameError: name 'stock_y_pred' is not defined

# %%
# stock_X_test

# %%
coefficients = regr.coef_ # array([[ 0.89269439]])
#     # mean squared error
#     # Explained variance score: 1 is perfect prediction
#     RSQ = r2_score(mark_y_test, mark_y_pred)
# stock_y_test.values.reshape((len(stock_y_test),1))

# %%
MSE = mean_squared_error(stock_y_test, stock_y_pred)
MSE
# Out:
# 3323.2163132907508

# %%
# RSQ = r2_score(stock_y_test, stock_y_pred)

# %%
plt.plot(stock_y_test)
plt.plot(stock_y_pred)

# %% [markdown]
# RMSE depends on the dependent variable. The unit of RMSE is same as dependent variable. If your data has a range of 0 to 100000 , it is pretty huge. If RMSE value of 3000 is small.
#
# Play with other input variables, and compare your RMSE values.
#
# The smaller the RMSE value, the better the model.
#
# Also, try to compare your RMSE values of both training and testing data. If they are almost similar, your model is good. If the RMSE for the testing data is much higher than that of the training data, it is likely that you've badly over fit the data.

# %%
mean_squared_error(stock_X_train, stock_y_train)
# Out:
# 29422.51360958592

# %%
mean_squared_error(stock_X_test, stock_y_test)
# Out:
# 15868.361142483302

# %%
# Split the data into training/testing sets
stock_X_train = stock_data[:450]
stock_X_test = stock_data[900:1077,]

# Split the targets into training/testing sets
stock_y_train = stock_data[450:900]
stock_y_test = stock_data[1077:1254]

# %%
regr = linear_model.LinearRegression()
regr.fit(stock_X_train, stock_y_train)
stock_y_pred = regr.predict(stock_X_test)

# %%
plt.plot(stock_y_test)
plt.plot(stock_y_pred)

# %%
mean_squared_error(stock_X_train, stock_y_train)
# Out:
# 24928.160078345074

# %%
mean_squared_error(stock_X_test, stock_y_test)
# Out:
# 17166.766332412433

# %%
df.columns
# Out:
# Index(['id', 'companyName', 'companyAbbr', 'date', 'open', 'high', 'low',
#        'close', 'adjClose', 'volume'],
#       dtype='object')

# %%
# filtering company
qs = StockData.objects.filter(companyAbbr = 'RUT') #RUSSELL 2000 INDEX(company name)
df = read_frame(qs)
data = df['open']
stock_data = np.array(data.values.reshape((len(data),1)))
stock_data.shape #(1258, 1)
# Out:
# (1258, 1)

# %%
# Split the data into training/testing sets
stock_X_train = stock_data[:350]
stock_X_test = stock_data[700:979,]

# Split the targets into training/testing sets
stock_y_train = stock_data[350:700]
stock_y_test = stock_data[979:]

# %%
regr = linear_model.LinearRegression()
regr.fit(stock_X_train, stock_y_train)
stock_y_pred = regr.predict(stock_X_test)

# %%
stock_y_pred
# Out:
# array([[ 1258.69863119],
#        [ 1256.38235843],
#        [ 1259.02017848],
#        [ 1257.26446859],
#        [ 1257.54047759],
#        [ 1261.58401169],
#        [ 1260.69620504],
#        [ 1258.93764676],
#        [ 1258.83521164],
#        [ 1262.91570417],
#        [ 1262.51447354],
#        [ 1266.36164754],
#        [ 1267.81005177],
#        [ 1268.8941838 ],
#        [ 1268.73485185],
#        [ 1266.78847834],
#        [ 1266.29335717],
#        [ 1261.77748869],
#        [ 1257.83642471],
#        [ 1259.71732152],
#        [ 1258.83805974],
#        [ 1253.20387919],
#        [ 1255.63682871],
#        [ 1253.16118928],
#        [ 1253.46852965],
#        [ 1254.8457607 ],
#        [ 1258.76976966],
#        [ 1260.62221819],
#        [ 1263.04092608],
#        [ 1262.27260986],
#        [ 1263.00393265],
#        [ 1261.6238185 ],
#        [ 1259.04293027],
#        [ 1256.08925969],
#        [ 1259.30188397],
#        [ 1254.10307937],
#        [ 1247.50710532],
#        [ 1247.58109217],
#        [ 1097.189941],
#        [ 1101.689941],
#        [ 1095.160034],
#        [ 1112.469971],
#        [ 1112.51001 ],
#        [ 1136.369995],
#        [ 1141.099976],
#        [ 1139.97998 ],
#        [ 1150.599976],
#        [ 1154.51001 ],
#        [ 1162.73999 ],
#        [ 1170.390015],
#        [ 1164.26001 ],
#        [ 1177.189941],
#        [ 1180.199951],
#        [ 1188.22998 ],
#        [ 1178.380005],
#        [ 1162.530029],
#        [ 1149.589966],
#        [ 1148.089966],
#        [ 1147.859985],
#        [ 1148.959961],
#        [ 1146.390015],
#        [ 1158.119995],
#        [ 1154.150024],
#        [ 1151.51001 ],
#        [ 1162.920044],
#        [ 1123.810059],
#        [ 1092.170044],
#        [ 1110.790039],
#        [ 1132.150024],
#        [ 1151.75    ],
#        [ 1155.459961],
#        [ 1138.920044],
#        [ 1147.630005],
#        [ 1152.23999 ],
#        [ 1179.189941],
#        [ 1191.97998 ]])

# %%
plt.plot(stock_y_test)
plt.plot(stock_y_pred)

# %%
mean_squared_error(stock_X_train, stock_y_train)
# Out:
# 52055.660790123271

# %%
mean_squared_error(stock_X_test, stock_y_test)
# Out:
# 53699.32588329909

# %% [markdown]
# Almost perfect fit

# %%
qs = StockData.objects.all()
df = read_frame(qs)
df
# Out:
#           id         companyName companyAbbr        date         open  \
# 0       1359        Alphabet Inc        GOOG  2012-08-20   336.488770
# 1       1360        Alphabet Inc        GOOG  2012-08-21   335.298218
# 2       1361        Alphabet Inc        GOOG  2012-08-22   332.443909
# 3       1362        Alphabet Inc        GOOG  2012-08-23   335.876068
# 4       1363        Alphabet Inc        GOOG  2012-08-24   336.538574
# 5       1364        Alphabet Inc        GOOG  2012-08-27   330.257111
# 6       1365        Alphabet Inc        GOOG  2012-08-28   331.258362
# 7       1366        Alphabet Inc        GOOG  2012-08-29   337.420258
# 8       1367        Alphabet Inc        GOOG  2012-08-30   340.842438
# 9       1368        Alphabet Inc        GOOG  2012-08-31   340.722900
# 10      1369        Alphabet Inc        GOOG  2012-09-04   340.996857
# 11      1370        Alphabet Inc        GOOG  2012-09-05   338.730347
# 12      1371        Alphabet Inc        GOOG  2012-09-06   341.699219
# 13      1372        Alphabet Inc        GOOG  2012-09-07   348.693024
# 14      1373        Alphabet Inc        GOOG  2012-09-10   353.554779
# 15      1374        Alphabet Inc        GOOG  2012-09-11   347.676819
# 16      1375        Alphabet Inc        GOOG  2012-09-12   343.417786
# 17      1376        Alphabet Inc        GOOG  2012-09-13   345.250916
# 18      1377        Alphabet Inc        GOOG  2012-09-14   353.475098
# 19      1378        Alphabet Inc        GOOG  2012-09-17   352.732880
# 20      1379        Alphabet Inc        GOOG  2012-09-18   352.568481
# 21      1380        Alphabet Inc        GOOG  2012-09-19   357.410339
# 22      1381        Alphabet Inc        GOOG  2012-09-20   360.882324
# 23      1382        Alphabet Inc        GOOG  2012-09-21   364.737885
# 24      1383        Alphabet Inc        GOOG  2012-09-24   364.135132
# 25      1384        Alphabet Inc        GOOG  2012-09-25   375.118958
# 37996  1396.599976  1372.540039  1372.540039  1372.540039  36210700.0
# 37997  1376.369995  1368.329956  1374.229980  1374.229980  31599300.0
# 37998  1394.530029  1375.130005  1394.310059  1394.310059  28225500.0
# 37999  1395.880005  1382.949951  1383.239990  1383.239990  29131000.0
# 38000  1391.680054  1381.900024  1383.530029  1383.530029  29536500.0
# 38001  1384.739990  1358.800049  1358.939941  1358.939941  31426200.0
# 38002  1362.339966  1349.349976  1357.790039  1357.790039  34156800.0
#
# [38003 rows x 10 columns]

# %%
all_companyAbbr = df['companyAbbr'].unique()

# %%
a = df[(df['companyAbbr'] == 'DJI')]
af = pd.pivot_table(a, values = 'open', index=['date'], columns = ['companyAbbr']).reset_index() #panas.core.frame.DataFrame
af.plot()
# af

# %%
qs = StockData.objects.filter(companyAbbr__in=all_companyAbbr)
df = read_frame(qs)
data = df['open']
data.shape
# Out:
# (38003,)

# %%
stock_data = np.array(data.values.reshape((len(data), 1)))#(38003,1)
# Split the data into training/testing sets
stock_X_train = stock_data[:11000]
stock_X_test = stock_data[22000:30000, ]

# Split the targets into training/testing sets
stock_y_train = stock_data[11000:22000]
stock_y_test = stock_data[30000:38000]

regr = linear_model.LinearRegression()
regr.fit(stock_X_train, stock_y_train)
stock_y_pred = regr.predict(stock_X_test)

# %%
plt.plot(stock_y_test)
plt.plot(stock_y_pred)

# %%
mean_squared_error(stock_X_train, stock_y_train)
# Out:
# 65826922.596087955

# %%
mean_squared_error(stock_X_test, stock_y_test)
# Out:
# 199738.24596233814

# %%
pd.pivot_table(df, values = 'open', index=['companyName'], columns = ['companyAbbr']).reset_index() #panas.core.frame.DataFrame
# Out:
# companyAbbr                               companyName        BAC        BHI  \
# 0                                        Alphabet Inc        NaN        NaN
# 1                           Baker Hughes Incorporated        NaN  39.956777
# 2                         Bank of America Corporation  16.064849        NaN
# 3                                  CBOE Interest Rate        NaN        NaN
# 4                                 Calpine Corporation        NaN        NaN
# 5                   Columbia Small Cap Value Fund I B        NaN        NaN
# 6                        Dow Jones Industrial Average        NaN        NaN
# 7                                   Foot Locker, Inc.        NaN        NaN
# 8                                  Ford Motor Company        NaN        NaN
# 9                            General Electric Company        NaN        NaN
# 10                                    Infosys Limited        NaN        NaN
# 11                           JPMorgan Latin America I        NaN        NaN
# 12                                   NASDAQ Composite        NaN        NaN
# 13                                         Nikkei 225        NaN        NaN
# 14            ProFunds UltraSector Oil & Gas Investor        NaN        NaN
# 15                 ProFunds UltraSector Oil & Gas Svc        NaN        NaN
# 16                                 RUSSELL 2000 INDEX        NaN        NaN
# 17                          Regal Entertainment Group        NaN        NaN
# 18                             Reynolds American Inc.        NaN        NaN
# 19                                  Ross Stores, Inc.        NaN        NaN
# 20                                            S&P 500        NaN        NaN
# 21                        Sally Beauty Holdings, Inc.        NaN        NaN
# 22                                          Snap Inc.        NaN        NaN
# 23                        T. Rowe Price Latin America        NaN        NaN
# 24                    The Estée Lauder Companies Inc.        NaN        NaN
# 25                                 VOLATILITY S&P 500        NaN        NaN
# 26                                       Viacom, Inc.        NaN        NaN
# 27                WisdomTree Middle East Dividend ETF        NaN        NaN
# 28                       iShares Latin America 40 ETF        NaN        NaN
# 29                      iShares MSCI Chile Capped ETF        NaN        NaN
# 30                      iShares MSCI South Africa ETF        NaN        NaN
# 31           iShares North American Tech-Software ETF        NaN        NaN
#
# companyAbbr        CPN      CSSBX           DJI        ECH         EL  \
# 0                  NaN        NaN           NaN        NaN        NaN
# 1                  NaN        NaN           NaN        NaN        NaN
# 2                  NaN        NaN           NaN        NaN        NaN
# 3                  NaN        NaN           NaN        NaN        NaN
# 4            17.549491        NaN           NaN        NaN        NaN
# 5                  NaN  32.756619           NaN        NaN        NaN
# 6                  NaN        NaN  17075.483003        NaN        NaN
# 7                  NaN        NaN           NaN        NaN        NaN
# 8                  NaN        NaN           NaN        NaN        NaN
# 9                  NaN        NaN           NaN        NaN        NaN
# 10                 NaN        NaN           NaN        NaN        NaN
# 11                 NaN        NaN           NaN        NaN        NaN
# 12                 NaN        NaN           NaN        NaN        NaN
# 13                 NaN        NaN           NaN        NaN        NaN
# 14                 NaN        NaN           NaN        NaN        NaN
# 15                 NaN        NaN           NaN        NaN        NaN
# 16                 NaN        NaN           NaN        NaN        NaN
# 17                 NaN        NaN           NaN        NaN        NaN
# 18                 NaN        NaN           NaN        NaN        NaN
# 19                 NaN        NaN           NaN        NaN        NaN
# 20                 NaN        NaN           NaN        NaN        NaN
# 21                 NaN        NaN           NaN        NaN        NaN
# 22                 NaN        NaN           NaN        NaN        NaN
# 23                 NaN        NaN           NaN        NaN        NaN
# 24                 NaN        NaN           NaN        NaN  78.447273
# 25                 NaN        NaN           NaN        NaN        NaN
# 26                 NaN        NaN           NaN        NaN        NaN
# 27                 NaN        NaN           NaN        NaN        NaN
# 28                 NaN        NaN           NaN        NaN        NaN
# 29                 NaN        NaN           NaN  44.600755        NaN
# 30                 NaN        NaN           NaN        NaN        NaN
# 31                 NaN        NaN           NaN        NaN        NaN
#
# companyAbbr     ENPIX      ENPSX    ...          PRLAX        RAI        RGC  \
# 0                 NaN        NaN    ...            NaN        NaN        NaN
# 1                 NaN        NaN    ...            NaN        NaN        NaN
# 2                 NaN        NaN    ...            NaN        NaN        NaN
# 3                 NaN        NaN    ...            NaN        NaN        NaN
# 4                 NaN        NaN    ...            NaN        NaN        NaN
# 5                 NaN        NaN    ...            NaN        NaN        NaN
# 6                 NaN        NaN    ...            NaN        NaN        NaN
# 7                 NaN        NaN    ...            NaN        NaN        NaN
# 8                 NaN        NaN    ...            NaN        NaN        NaN
# 9                 NaN        NaN    ...            NaN        NaN        NaN
# 10                NaN        NaN    ...            NaN        NaN        NaN
# 11                NaN        NaN    ...            NaN        NaN        NaN
# 12                NaN        NaN    ...            NaN        NaN        NaN
# 13                NaN        NaN    ...            NaN        NaN        NaN
# 14           43.40318        NaN    ...            NaN        NaN        NaN
# 15                NaN  37.713211    ...            NaN        NaN        NaN
# 16                NaN        NaN    ...            NaN        NaN        NaN
# 17                NaN        NaN    ...            NaN        NaN  19.603275
# 18                NaN        NaN    ...            NaN  38.249968        NaN
# 19                NaN        NaN    ...            NaN        NaN        NaN
# 20                NaN        NaN    ...            NaN        NaN        NaN
# 21                NaN        NaN    ...            NaN        NaN        NaN
# 22                NaN        NaN    ...            NaN        NaN        NaN
# 23                NaN        NaN    ...      27.733897        NaN        NaN
# 24                NaN        NaN    ...            NaN        NaN        NaN
# 25                NaN        NaN    ...            NaN        NaN        NaN
# 26                NaN        NaN    ...            NaN        NaN        NaN
# 27                NaN        NaN    ...            NaN        NaN        NaN
# 28                NaN        NaN    ...            NaN        NaN        NaN
# 29                NaN        NaN    ...            NaN        NaN        NaN
# 30                NaN        NaN    ...            NaN        NaN        NaN
# 31                NaN        NaN    ...            NaN        NaN        NaN
#
# companyAbbr       ROST          RUT        SBH       SNAP      TNX        VIA  \
# 0                  NaN          NaN        NaN        NaN      NaN        NaN
# 1                  NaN          NaN        NaN        NaN      NaN        NaN
# 2                  NaN          NaN        NaN        NaN      NaN        NaN
# 3                  NaN          NaN        NaN        NaN  2.15818        NaN
# 4                  NaN          NaN        NaN        NaN      NaN        NaN
# 5                  NaN          NaN        NaN        NaN      NaN        NaN
# 6                  NaN          NaN        NaN        NaN      NaN        NaN
# 7                  NaN          NaN        NaN        NaN      NaN        NaN
# 8                  NaN          NaN        NaN        NaN      NaN        NaN
# 9                  NaN          NaN        NaN        NaN      NaN        NaN
# 10                 NaN          NaN        NaN        NaN      NaN        NaN
# 11                 NaN          NaN        NaN        NaN      NaN        NaN
# 12                 NaN          NaN        NaN        NaN      NaN        NaN
# 13                 NaN          NaN        NaN        NaN      NaN        NaN
# 14                 NaN          NaN        NaN        NaN      NaN        NaN
# 15                 NaN          NaN        NaN        NaN      NaN        NaN
# 16                 NaN  1144.014816        NaN        NaN      NaN        NaN
# 17                 NaN          NaN        NaN        NaN      NaN        NaN
# 18                 NaN          NaN        NaN        NaN      NaN        NaN
# 19           46.181395          NaN        NaN        NaN      NaN        NaN
# 20                 NaN          NaN        NaN        NaN      NaN        NaN
# 21                 NaN          NaN  27.191256        NaN      NaN        NaN
# 22                 NaN          NaN        NaN  18.939832      NaN        NaN
# 23                 NaN          NaN        NaN        NaN      NaN        NaN
# 24                 NaN          NaN        NaN        NaN      NaN        NaN
# 25                 NaN          NaN        NaN        NaN      NaN        NaN
# 26                 NaN          NaN        NaN        NaN      NaN  60.656137
# 27                 NaN          NaN        NaN        NaN      NaN        NaN
# 28                 NaN          NaN        NaN        NaN      NaN        NaN
# 29                 NaN          NaN        NaN        NaN      NaN        NaN
# 30                 NaN          NaN        NaN        NaN      NaN        NaN
# 31                 NaN          NaN        NaN        NaN      NaN        NaN
#
# companyAbbr        VIX
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25           14.902949
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
#
# [32 rows x 33 columns]
